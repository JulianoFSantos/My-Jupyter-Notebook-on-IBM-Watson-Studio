# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Juliano Fagundes dos Santos**
#
# Professor

# %% [markdown]
# *I am interested in data science because as a professor, I want to extract as much knowledge as possible from data and be able to contribute to Education.*

# %% [markdown]
# <h3>Adding two numbers</h3>

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# **Best Education System In The World (numbered list):**
#
# 1. United Kingdom
# 1. United States
# 1. Australia
# 1. Netherlands
# 1. Sweden
#
#
# __[Best Education System list hyperlink](http://leverageedu.com/blog/best-education-system-in-the-world/)__
#
#
#
#
#
# ![imagem.PNG](attachment:imagem.PNG)
